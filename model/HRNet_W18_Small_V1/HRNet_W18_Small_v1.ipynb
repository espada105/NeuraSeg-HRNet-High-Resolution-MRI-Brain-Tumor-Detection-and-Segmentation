# %% [markdown]
# 1. Colab 런타임 준비
# GPU 활성화
#
# 메뉴 > 런타임 > 런타임 유형 변경에서 하드웨어 가속기: GPU 선택
#
# 구글 드라이브 마운트 (선택 사항)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2. HRNet-Image-Classification 레포지토리 클론 및 의존성 설치

# %%
# 레포지토리 클론
# !git clone https://github.com/HRNet/HRNet-Image-Classification.git
# %cd HRNet-Image-Classification

# 필요 패키지 설치 (torch, torchvision 등)
# !pip install -r requirements.txt

# Hugging Face Datasets 설치
# !pip install datasets
# Out:
# Cloning into 'HRNet-Image-Classification'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 169 (delta 52), reused 41 (delta 41), pack-reused 104 (from 1)
# Receiving objects: 100% (169/169), 186.75 KiB | 975.00 KiB/s, done.
# Resolving deltas: 100% (94/94), done.
# /content/HRNet-Image-Classification
# Collecting EasyDict==1.7 (from -r requirements.txt (line 1))
#   Downloading easydict-1.7.tar.gz (6.2 kB)
#   Preparing metadata (setup.py) ... done
# ERROR: Ignored the following yanked versions: 3.4.11.39, 3.4.17.61, 4.4.0.42, 4.4.0.44, 4.5.4.58, 4.5.5.62, 4.7.0.68
# ERROR: Could not find a version that satisfies the requirement opencv-python==3.4.1.15 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.60, 4.5.5.64, 4.6.0.66, 4.7.0.72, 4.8.0.74, 4.8.0.76, 4.8.1.78, 4.9.0.80, 4.10.0.82, 4.10.0.84, 4.11.0.86)
# ERROR: No matching distribution found for opencv-python==3.4.1.15
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 12.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install tensorboardX
# !pip install yacs
# !pip install _init_paths
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (5.29.4)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from yacs) (6.0.2)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8
# ERROR: Invalid requirement: '_init_paths': Expected package name at the start of dependency specifier
#     _init_paths
#     ^

# %% [markdown]
# 3. 데이터셋 로딩 및 분류용 전처리
# Hugging Face segmentation 데이터셋을 로드한 뒤, 마스크 유무로 0/1 레이블을 만든 뒤 로컬에 ImageFolder 구조로 저장합니다.

# %%
#데이터셋 증강 적용
from datasets import load_dataset
from PIL import Image
import os

# 1) 원본 HF 데이터셋 로드
#    train · 7.51k, test · 1.08k, valid · 2.15k rows
ds = load_dataset("espada105/augmented-brain-tumor-segmentation-v2")

# 2) 저장할 폴더 구조 생성 (이미 train/val 폴더가 만들어져 있다면 test만 추가)
base = "/content/HRNet-Image-Classification/brain_tumor_classification/imagenet/images"
for phase in ("train","val","test"):
    for cls in ("no_tumor","tumor"):
        os.makedirs(f"{base}/{phase}/{cls}", exist_ok=True)

# 3) split별로 이미지 저장 함수
def save_split(split_ds, phase):
    for i, item in enumerate(split_ds):
        img: Image.Image = item["image"]
        cid = int(item["category_id"])
        # (1=no_tumor, 2=tumor)
        label = "tumor"    if cid == 2 else \
                "no_tumor" if cid == 1 else None
        if label is None:
            continue
        img.save(f"{base}/{phase}/{label}/{i}.png")

# 4) train/val/test 각각 뽑아서 저장
save_split(ds["train"], "train")
save_split(ds["valid"], "val")
save_split(ds["test"],  "test")

# 5) 결과 확인
print("Train/Tumor   :", len(os.listdir(f"{base}/train/tumor")))
print("Train/NoTumor :", len(os.listdir(f"{base}/train/no_tumor")))
print("Val/Tumor     :", len(os.listdir(f"{base}/val/tumor")))
print("Val/NoTumor   :", len(os.listdir(f"{base}/val/no_tumor")))
print("Test/Tumor    :", len(os.listdir(f"{base}/test/tumor")))
print("Test/NoTumor  :", len(os.listdir(f"{base}/test/no_tumor")))
# Out:
# README.md:   0%|          | 0.00/814 [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/407M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/404M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/407M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/234M [00:00<?, ?B/s]
# valid-00000-of-00001.parquet:   0%|          | 0.00/462M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7510 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1075 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/2145 [00:00<?, ? examples/s]
# Train/Tumor   : 3976
# Train/NoTumor : 4169
# Val/Tumor     : 1169
# Val/NoTumor   : 1125
# Test/Tumor    : 485
# Test/NoTumor  : 590

# %%
#원본 데이터셋
from datasets import load_dataset
from PIL import Image
import os

# 1) 데이터 로드 및 train/val split (원본 train 1502장을 80/20으로)
ds = load_dataset(
    "dwb2023/brain-tumor-image-dataset-semantic-segmentation"
)
train_ds, val_ds, test_ds = (
    ds["train"].train_test_split(test_size=0.2, seed=42)["train"],
    ds["train"].train_test_split(test_size=0.2, seed=42)["test"],
    ds["test"],  # test 스플릿 215장
)

# 2) 저장할 폴더 구조 생성 (train, val, test)
base = "/content/HRNet-Image-Classification/brain_tumor_classification/imagenet/images"
for phase in ("train", "val", "test"):
    for cls in ("no_tumor", "tumor"):
        os.makedirs(f"{base}/{phase}/{cls}", exist_ok=True)

# 3) category_id 로 레이블링 후 저장 함수
def save_split(split_ds, phase):
    for i, item in enumerate(split_ds):
        img = item["image"]
        cid = int(item["category_id"])
        # 1 → no_tumor, 2 → tumor
        label = "tumor"    if cid == 2 else \
                "no_tumor" if cid == 1 else None
        if label is None:
            continue
        img.save(f"{base}/{phase}/{label}/{i}.png")

# 4) 각 스플릿 저장
save_split(train_ds, "train")
save_split(val_ds,   "val")
save_split(test_ds,  "test")

# 5) 결과 확인
print("Train/Tumor   :", len(os.listdir(f"{base}/train/tumor")))
print("Train/NoTumor :", len(os.listdir(f"{base}/train/no_tumor")))
print("Val/Tumor     :", len(os.listdir(f"{base}/val/tumor")))
print("Val/NoTumor   :", len(os.listdir(f"{base}/val/no_tumor")))
print("Test/Tumor    :", len(os.listdir(f"{base}/test/tumor")))
print("Test/NoTumor  :", len(os.listdir(f"{base}/test/no_tumor")))
# Out:
# README.md:   0%|          | 0.00/6.22k [00:00<?, ?B/s]
# (…)-00000-of-00001-1d7ef230dfbdad78.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# (…)-00000-of-00001-0031debf8df4462b.parquet:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# (…)-00000-of-00001-bce5cef16a5cce11.parquet:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1502 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/215 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/429 [00:00<?, ? examples/s]
# Train/Tumor   : 578
# Train/NoTumor : 623
# Val/Tumor     : 153
# Val/NoTumor   : 148
# Test/Tumor    : 97
# Test/NoTumor  : 118

# %%
# Colab 셀에서
# !find . -maxdepth 2 -type f -name "*.yaml"
# Out:
# ./experiments/cls_hrnet_w30_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w32_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w64_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w40_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w44_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w18_small_v2_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w48_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w18_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# ./experiments/cls_hrnet_w18_small_v1_sgd_lr5e-2_wd1e-4_bs32_x100.yaml

# %%
# HRNet-w18-small-v1
# %cd /content/HRNet-Image-Classification
# !cp experiments/cls_hrnet_w18_small_v1_sgd_lr5e-2_wd1e-4_bs32_x100.yaml experiments/cls_hrnet_brain_tumor_small.yaml
# Out:
# /content/HRNet-Image-Classification

# %%
# HRNet-w64
# %cd /content/HRNet-Image-Classification
# !cp experiments/cls_hrnet_w64_sgd_lr5e-2_wd1e-4_bs32_x100.yaml experiments/cls_hrnet_brain_tumor.yaml
# Out:
# /content/HRNet-Image-Classification

# %%
# %%bash
# sed -i 's|^  ROOT:.*|  ROOT: "/content/brain_tumor_classification"|' \
#     experiments/cls_hrnet_brain_tumor.yaml
# sed -i 's|^  NUM_CLASSES:.*|  NUM_CLASSES: 2|' \
#     experiments/cls_hrnet_brain_tumor.yaml

# %%
# %pwd
# Out:
# '/content/HRNet-Image-Classification'

# %%
# !ls experiments
# Out:
# cls_hrnet_brain_tumor.yaml
# cls_hrnet_w18_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w18_small_v1_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w18_small_v2_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w30_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w32_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w40_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w44_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w48_sgd_lr5e-2_wd1e-4_bs32_x100.yaml
# cls_hrnet_w64_sgd_lr5e-2_wd1e-4_bs32_x100.yaml

# %%
# !find /content/brain_tumor_classification/images -type d -name ".ipynb_checkpoints" -exec rm -rf {} +
# Out:
# find: ‘/content/brain_tumor_classification/images’: No such file or directory

# %%
# %%bash
# # brain_tumor_classification 아래 모든 .ipynb_checkpoints 폴더를 찾아 삭제
# find /content/HRNet-Image-Classification/brain_tumor_classification \
#      -type d -name ".ipynb_checkpoints" \
#      -exec rm -rf {} +

# %%
# !python tools/train.py \
  --cfg experiments/cls_hrnet_brain_tumor_small.yaml \
  --dataDir "/content/HRNet-Image-Classification/brain_tumor_classification"
# Out:
# => creating /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# => creating log/imagenet/cls_hrnet/cls_hrnet_brain_tumor_small_2025-05-04-14-24
# Namespace(cfg='experiments/cls_hrnet_brain_tumor_small.yaml', modelDir='', logDir='', dataDir='/content/HRNet-Image-Classification/brain_tumor_classification', testModel='')
# CfgNode({'OUTPUT_DIR': '/content/drive/MyDrive/Tumor_w18_Small_Output', 'LOG_DIR': 'log/', 'DATA_DIR': '/content/HRNet-Image-Classification/brain_tumor_classification', 'GPUS': (0,), 'WORKERS': 4, 'PRINT_FREQ': 1000, 'AUTO_RESUME': False, 'PIN_MEMORY': True, 'RANK': 0, 'CUDNN': CfgNode({'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True}), 'MODEL': CfgNode({'NAME': 'cls_hrnet', 'INIT_WEIGHTS': True, 'PRETRAINED': '', 'NUM_JOINTS': 17, 'NUM_CLASSES': 1000, 'TAG_PER_JOINT': True, 'TARGET_TYPE': 'gaussian', 'IMAGE_SIZE': [224, 224], 'HEATMAP_SIZE': [64, 64], 'SIGMA': 2, 'EXTRA': CfgNode({'WITH_HEAD': True, 'STAGE1': CfgNode({'NUM_MODULES': 1, 'NUM_RANCHES': 1, 'BLOCK': 'BOTTLENECK', 'NUM_BLOCKS': [1], 'NUM_CHANNELS': [32], 'FUSE_METHOD': 'SUM'}), 'STAGE2': CfgNode({'NUM_MODULES': 1, 'NUM_BRANCHES': 2, 'BLOCK': 'BASIC', 'NUM_BLOCKS': [2, 2], 'NUM_CHANNELS': [16, 32], 'FUSE_METHOD': 'SUM'}), 'STAGE3': CfgNode({'NUM_MODULES': 1, 'NUM_BRANCHES': 3, 'BLOCK': 'BASIC', 'NUM_BLOCKS': [2, 2, 2], 'NUM_CHANNELS': [16, 32, 64], 'FUSE_METHOD': 'SUM'}), 'STAGE4': CfgNode({'NUM_MODULES': 1, 'NUM_BRANCHES': 4, 'BLOCK': 'BASIC', 'NUM_BLOCKS': [2, 2, 2, 2], 'NUM_CHANNELS': [16, 32, 64, 128], 'FUSE_METHOD': 'SUM'})})}), 'LOSS': CfgNode({'USE_OHKM': False, 'TOPK': 8, 'USE_TARGET_WEIGHT': True, 'USE_DIFFERENT_JOINTS_WEIGHT': False}), 'DATASET': CfgNode({'ROOT': '/content/HRNet-Image-Classification/brain_tumor_classification/imagenet/images', 'DATASET': 'imagenet', 'TRAIN_SET': 'train', 'TEST_SET': 'test', 'DATA_FORMAT': 'png', 'HYBRID_JOINTS_TYPE': '', 'SELECT_DATA': False, 'FLIP': True, 'SCALE_FACTOR': 0.25, 'ROT_FACTOR': 30, 'PROB_HALF_BODY': 0.0, 'NUM_JOINTS_HALF_BODY': 8, 'COLOR_RGB': False}), 'TRAIN': CfgNode({'LR_FACTOR': 0.1, 'LR_STEP': [30, 60, 90], 'LR': 0.02, 'OPTIMIZER': 'sgd', 'MOMENTUM': 0.9, 'WD': 0.0005, 'NESTEROV': True, 'GAMMA1': 0.99, 'GAMMA2': 0.0, 'BEGIN_EPOCH': 0, 'END_EPOCH': 100, 'RESUME': False, 'CHECKPOINT': '', 'BATCH_SIZE_PER_GPU': 32, 'SHUFFLE': True}), 'TEST': CfgNode({'BATCH_SIZE_PER_GPU': 32, 'FLIP_TEST': False, 'POST_PROCESS': False, 'SHIFT_HEATMAP': False, 'USE_GT_BBOX': False, 'IMAGE_THRE': 0.1, 'NMS_THRE': 0.6, 'SOFT_NMS': False, 'OKS_THRE': 0.5, 'IN_VIS_THRE': 0.0, 'COCO_BBOX_FILE': '', 'BBOX_THRE': 1.0, 'MODEL_FILE': ''}), 'DEBUG': CfgNode({'DEBUG': False, 'SAVE_BATCH_IMAGES_GT': False, 'SAVE_BATCH_IMAGES_PRED': False, 'SAVE_HEATMAPS_GT': False, 'SAVE_HEATMAPS_PRED': False})})
# => init weights from normal distribution
#
# Total Parameters: 13,187,464
# ----------------------------------------------------------------------------------------------------------------------------------
# Total Multiply Adds (For Convolution and Linear Layers only): 1.491520881652832 GFLOPs
# ----------------------------------------------------------------------------------------------------------------------------------
# Number of Layers
# Conv2d : 91 layers   BatchNorm2d : 91 layers   ReLU : 75 layers   Bottleneck : 5 layers   BasicBlock : 18 layers   Upsample : 10 layers   HighResolutionModule : 3 layers   Linear : 1 layers
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch: [0][0/38]	Time 2.551s (2.551s)	Speed 12.5 samples/s	Data 0.576s (0.576s)	Loss 6.97291 (6.97291)	Accuracy@1 0.000 (0.000)	Accuracy@5 0.000 (0.000)
# Test: Time 0.201	Loss 0.4868	Error@1 18.605	Error@5 0.000	Accuracy@1 81.395	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [1][0/38]	Time 0.654s (0.654s)	Speed 48.9 samples/s	Data 0.557s (0.557s)	Loss 0.49478 (0.49478)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.167	Loss 1.8013	Error@1 45.116	Error@5 0.000	Accuracy@1 54.884	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [2][0/38]	Time 0.644s (0.644s)	Speed 49.7 samples/s	Data 0.556s (0.556s)	Loss 0.74734 (0.74734)	Accuracy@1 71.875 (71.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.2683	Error@1 10.698	Error@5 0.000	Accuracy@1 89.302	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [3][0/38]	Time 0.685s (0.685s)	Speed 46.7 samples/s	Data 0.602s (0.602s)	Loss 0.22391 (0.22391)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.3244	Error@1 10.698	Error@5 0.000	Accuracy@1 89.302	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [4][0/38]	Time 0.674s (0.674s)	Speed 47.5 samples/s	Data 0.581s (0.581s)	Loss 0.66996 (0.66996)	Accuracy@1 68.750 (68.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.3118	Error@1 12.093	Error@5 0.000	Accuracy@1 87.907	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [5][0/38]	Time 0.672s (0.672s)	Speed 47.6 samples/s	Data 0.587s (0.587s)	Loss 0.37936 (0.37936)	Accuracy@1 81.250 (81.250)	Accuracy@5 100.000 (100.000)
# Test: Time 0.167	Loss 0.2953	Error@1 14.884	Error@5 0.000	Accuracy@1 85.116	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [6][0/38]	Time 0.673s (0.673s)	Speed 47.5 samples/s	Data 0.589s (0.589s)	Loss 0.17158 (0.17158)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.2501	Error@1 11.163	Error@5 0.000	Accuracy@1 88.837	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [7][0/38]	Time 0.652s (0.652s)	Speed 49.0 samples/s	Data 0.555s (0.555s)	Loss 0.54461 (0.54461)	Accuracy@1 78.125 (78.125)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.3693	Error@1 16.279	Error@5 0.000	Accuracy@1 83.721	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [8][0/38]	Time 0.648s (0.648s)	Speed 49.4 samples/s	Data 0.558s (0.558s)	Loss 0.18212 (0.18212)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.3129	Error@1 10.698	Error@5 0.000	Accuracy@1 89.302	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [9][0/38]	Time 0.654s (0.654s)	Speed 48.9 samples/s	Data 0.560s (0.560s)	Loss 0.41045 (0.41045)	Accuracy@1 78.125 (78.125)	Accuracy@5 100.000 (100.000)
# Test: Time 0.166	Loss 0.2334	Error@1 8.372	Error@5 0.000	Accuracy@1 91.628	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [10][0/38]	Time 0.655s (0.655s)	Speed 48.8 samples/s	Data 0.558s (0.558s)	Loss 0.27845 (0.27845)	Accuracy@1 84.375 (84.375)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.2363	Error@1 10.233	Error@5 0.000	Accuracy@1 89.767	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [11][0/38]	Time 0.683s (0.683s)	Speed 46.8 samples/s	Data 0.595s (0.595s)	Loss 0.43734 (0.43734)	Accuracy@1 81.250 (81.250)	Accuracy@5 100.000 (100.000)
# Test: Time 0.166	Loss 0.1466	Error@1 5.116	Error@5 0.000	Accuracy@1 94.884	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [12][0/38]	Time 0.648s (0.648s)	Speed 49.4 samples/s	Data 0.563s (0.563s)	Loss 0.22490 (0.22490)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.1835	Error@1 7.907	Error@5 0.000	Accuracy@1 92.093	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [13][0/38]	Time 0.679s (0.679s)	Speed 47.1 samples/s	Data 0.583s (0.583s)	Loss 0.19432 (0.19432)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.4333	Error@1 15.349	Error@5 0.000	Accuracy@1 84.651	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [14][0/38]	Time 0.654s (0.654s)	Speed 48.9 samples/s	Data 0.554s (0.554s)	Loss 0.23318 (0.23318)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.2873	Error@1 13.488	Error@5 0.000	Accuracy@1 86.512	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [15][0/38]	Time 0.650s (0.650s)	Speed 49.2 samples/s	Data 0.553s (0.553s)	Loss 0.02313 (0.02313)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.2238	Error@1 7.907	Error@5 0.000	Accuracy@1 92.093	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [16][0/38]	Time 0.664s (0.664s)	Speed 48.2 samples/s	Data 0.578s (0.578s)	Loss 0.09483 (0.09483)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.2006	Error@1 6.047	Error@5 0.000	Accuracy@1 93.953	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [17][0/38]	Time 0.643s (0.643s)	Speed 49.8 samples/s	Data 0.553s (0.553s)	Loss 0.23250 (0.23250)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.2708	Error@1 13.023	Error@5 0.000	Accuracy@1 86.977	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [18][0/38]	Time 0.642s (0.642s)	Speed 49.8 samples/s	Data 0.553s (0.553s)	Loss 0.41261 (0.41261)	Accuracy@1 84.375 (84.375)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.3860	Error@1 15.349	Error@5 0.000	Accuracy@1 84.651	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [19][0/38]	Time 0.646s (0.646s)	Speed 49.5 samples/s	Data 0.554s (0.554s)	Loss 0.78934 (0.78934)	Accuracy@1 71.875 (71.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.2955	Error@1 13.953	Error@5 0.000	Accuracy@1 86.047	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [20][0/38]	Time 0.676s (0.676s)	Speed 47.3 samples/s	Data 0.578s (0.578s)	Loss 0.44233 (0.44233)	Accuracy@1 71.875 (71.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.167	Loss 0.2553	Error@1 11.628	Error@5 0.000	Accuracy@1 88.372	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [21][0/38]	Time 0.652s (0.652s)	Speed 49.1 samples/s	Data 0.561s (0.561s)	Loss 0.30256 (0.30256)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.1355	Error@1 6.512	Error@5 0.000	Accuracy@1 93.488	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [22][0/38]	Time 0.676s (0.676s)	Speed 47.3 samples/s	Data 0.591s (0.591s)	Loss 0.20029 (0.20029)	Accuracy@1 84.375 (84.375)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.2550	Error@1 13.023	Error@5 0.000	Accuracy@1 86.977	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [23][0/38]	Time 0.669s (0.669s)	Speed 47.8 samples/s	Data 0.584s (0.584s)	Loss 0.19643 (0.19643)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.1172	Error@1 2.791	Error@5 0.000	Accuracy@1 97.209	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [24][0/38]	Time 0.647s (0.647s)	Speed 49.4 samples/s	Data 0.548s (0.548s)	Loss 0.18887 (0.18887)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0747	Error@1 2.326	Error@5 0.000	Accuracy@1 97.674	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [25][0/38]	Time 0.661s (0.661s)	Speed 48.4 samples/s	Data 0.574s (0.574s)	Loss 0.21746 (0.21746)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.166	Loss 0.0827	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [26][0/38]	Time 0.641s (0.641s)	Speed 49.9 samples/s	Data 0.552s (0.552s)	Loss 0.13470 (0.13470)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.1708	Error@1 7.907	Error@5 0.000	Accuracy@1 92.093	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [27][0/38]	Time 0.660s (0.660s)	Speed 48.5 samples/s	Data 0.568s (0.568s)	Loss 0.19936 (0.19936)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0806	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [28][0/38]	Time 0.668s (0.668s)	Speed 47.9 samples/s	Data 0.578s (0.578s)	Loss 0.02818 (0.02818)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.1616	Error@1 6.047	Error@5 0.000	Accuracy@1 93.953	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [29][0/38]	Time 0.672s (0.672s)	Speed 47.6 samples/s	Data 0.587s (0.587s)	Loss 0.35148 (0.35148)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.0732	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [30][0/38]	Time 0.655s (0.655s)	Speed 48.9 samples/s	Data 0.556s (0.556s)	Loss 0.12377 (0.12377)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0679	Error@1 2.326	Error@5 0.000	Accuracy@1 97.674	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [31][0/38]	Time 0.674s (0.674s)	Speed 47.5 samples/s	Data 0.582s (0.582s)	Loss 0.21773 (0.21773)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.0645	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [32][0/38]	Time 0.666s (0.666s)	Speed 48.0 samples/s	Data 0.569s (0.569s)	Loss 0.03863 (0.03863)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.165	Loss 0.0592	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [33][0/38]	Time 0.660s (0.660s)	Speed 48.5 samples/s	Data 0.563s (0.563s)	Loss 0.13017 (0.13017)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0492	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [34][0/38]	Time 0.632s (0.632s)	Speed 50.6 samples/s	Data 0.543s (0.543s)	Loss 0.06568 (0.06568)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0525	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [35][0/38]	Time 0.651s (0.651s)	Speed 49.2 samples/s	Data 0.561s (0.561s)	Loss 0.06001 (0.06001)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.0517	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [36][0/38]	Time 0.678s (0.678s)	Speed 47.2 samples/s	Data 0.585s (0.585s)	Loss 0.10457 (0.10457)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0451	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [37][0/38]	Time 0.645s (0.645s)	Speed 49.6 samples/s	Data 0.544s (0.544s)	Loss 0.02695 (0.02695)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.0468	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [38][0/38]	Time 0.647s (0.647s)	Speed 49.5 samples/s	Data 0.552s (0.552s)	Loss 0.08736 (0.08736)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0510	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [39][0/38]	Time 0.646s (0.646s)	Speed 49.5 samples/s	Data 0.550s (0.550s)	Loss 0.30394 (0.30394)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0517	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [40][0/38]	Time 0.666s (0.666s)	Speed 48.0 samples/s	Data 0.583s (0.583s)	Loss 0.12490 (0.12490)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0596	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [41][0/38]	Time 0.673s (0.673s)	Speed 47.6 samples/s	Data 0.583s (0.583s)	Loss 0.03227 (0.03227)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.0541	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [42][0/38]	Time 0.641s (0.641s)	Speed 50.0 samples/s	Data 0.552s (0.552s)	Loss 0.08471 (0.08471)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0523	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [43][0/38]	Time 0.643s (0.643s)	Speed 49.8 samples/s	Data 0.555s (0.555s)	Loss 0.09287 (0.09287)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0418	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [44][0/38]	Time 0.651s (0.651s)	Speed 49.1 samples/s	Data 0.558s (0.558s)	Loss 0.03452 (0.03452)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0508	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [45][0/38]	Time 0.647s (0.647s)	Speed 49.4 samples/s	Data 0.561s (0.561s)	Loss 0.02432 (0.02432)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0522	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [46][0/38]	Time 0.651s (0.651s)	Speed 49.1 samples/s	Data 0.566s (0.566s)	Loss 0.02954 (0.02954)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0592	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [47][0/38]	Time 0.659s (0.659s)	Speed 48.6 samples/s	Data 0.574s (0.574s)	Loss 0.04324 (0.04324)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0578	Error@1 2.326	Error@5 0.000	Accuracy@1 97.674	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [48][0/38]	Time 0.649s (0.649s)	Speed 49.3 samples/s	Data 0.555s (0.555s)	Loss 0.04995 (0.04995)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.0444	Error@1 0.465	Error@5 0.000	Accuracy@1 99.535	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [49][0/38]	Time 0.678s (0.678s)	Speed 47.2 samples/s	Data 0.587s (0.587s)	Loss 0.23512 (0.23512)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0488	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [50][0/38]	Time 0.637s (0.637s)	Speed 50.2 samples/s	Data 0.543s (0.543s)	Loss 0.04582 (0.04582)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0453	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [51][0/38]	Time 0.646s (0.646s)	Speed 49.6 samples/s	Data 0.555s (0.555s)	Loss 0.05802 (0.05802)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0537	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [52][0/38]	Time 0.670s (0.670s)	Speed 47.8 samples/s	Data 0.587s (0.587s)	Loss 0.06095 (0.06095)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0577	Error@1 2.326	Error@5 0.000	Accuracy@1 97.674	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [53][0/38]	Time 0.638s (0.638s)	Speed 50.1 samples/s	Data 0.545s (0.545s)	Loss 0.09246 (0.09246)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0475	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [54][0/38]	Time 0.671s (0.671s)	Speed 47.7 samples/s	Data 0.582s (0.582s)	Loss 0.07016 (0.07016)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0505	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [55][0/38]	Time 0.640s (0.640s)	Speed 50.0 samples/s	Data 0.554s (0.554s)	Loss 0.04802 (0.04802)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0549	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [56][0/38]	Time 0.641s (0.641s)	Speed 49.9 samples/s	Data 0.544s (0.544s)	Loss 0.04185 (0.04185)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0729	Error@1 3.721	Error@5 0.000	Accuracy@1 96.279	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [57][0/38]	Time 0.634s (0.634s)	Speed 50.5 samples/s	Data 0.545s (0.545s)	Loss 0.11375 (0.11375)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0516	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [58][0/38]	Time 0.646s (0.646s)	Speed 49.5 samples/s	Data 0.554s (0.554s)	Loss 0.10845 (0.10845)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0671	Error@1 2.791	Error@5 0.000	Accuracy@1 97.209	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [59][0/38]	Time 0.661s (0.661s)	Speed 48.4 samples/s	Data 0.577s (0.577s)	Loss 0.08875 (0.08875)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0495	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [60][0/38]	Time 0.640s (0.640s)	Speed 50.0 samples/s	Data 0.552s (0.552s)	Loss 0.10593 (0.10593)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.0558	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [61][0/38]	Time 0.626s (0.626s)	Speed 51.1 samples/s	Data 0.535s (0.535s)	Loss 0.11796 (0.11796)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0537	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [62][0/38]	Time 0.647s (0.647s)	Speed 49.5 samples/s	Data 0.557s (0.557s)	Loss 0.07215 (0.07215)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0468	Error@1 0.465	Error@5 0.000	Accuracy@1 99.535	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [63][0/38]	Time 0.662s (0.662s)	Speed 48.3 samples/s	Data 0.570s (0.570s)	Loss 0.09047 (0.09047)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0525	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [64][0/38]	Time 0.826s (0.826s)	Speed 38.8 samples/s	Data 0.740s (0.740s)	Loss 0.07000 (0.07000)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0500	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [65][0/38]	Time 0.661s (0.661s)	Speed 48.4 samples/s	Data 0.567s (0.567s)	Loss 0.09850 (0.09850)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.0521	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [66][0/38]	Time 0.653s (0.653s)	Speed 49.0 samples/s	Data 0.558s (0.558s)	Loss 0.17493 (0.17493)	Accuracy@1 87.500 (87.500)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0513	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [67][0/38]	Time 0.667s (0.667s)	Speed 48.0 samples/s	Data 0.572s (0.572s)	Loss 0.10037 (0.10037)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.0518	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [68][0/38]	Time 0.650s (0.650s)	Speed 49.2 samples/s	Data 0.552s (0.552s)	Loss 0.16762 (0.16762)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0481	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [69][0/38]	Time 0.657s (0.657s)	Speed 48.7 samples/s	Data 0.559s (0.559s)	Loss 0.03193 (0.03193)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0510	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [70][0/38]	Time 0.653s (0.653s)	Speed 49.0 samples/s	Data 0.567s (0.567s)	Loss 0.06915 (0.06915)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0468	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [71][0/38]	Time 0.658s (0.658s)	Speed 48.6 samples/s	Data 0.571s (0.571s)	Loss 0.19238 (0.19238)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.0475	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [72][0/38]	Time 0.649s (0.649s)	Speed 49.3 samples/s	Data 0.557s (0.557s)	Loss 0.16688 (0.16688)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0476	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [73][0/38]	Time 0.652s (0.652s)	Speed 49.1 samples/s	Data 0.554s (0.554s)	Loss 0.07448 (0.07448)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0495	Error@1 1.860	Error@5 0.000	Accuracy@1 98.140	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [74][0/38]	Time 0.653s (0.653s)	Speed 49.0 samples/s	Data 0.563s (0.563s)	Loss 0.30036 (0.30036)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0533	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [75][0/38]	Time 0.659s (0.659s)	Speed 48.6 samples/s	Data 0.571s (0.571s)	Loss 0.25894 (0.25894)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.162	Loss 0.0443	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [76][0/38]	Time 0.635s (0.635s)	Speed 50.4 samples/s	Data 0.550s (0.550s)	Loss 0.03408 (0.03408)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0528	Error@1 2.791	Error@5 0.000	Accuracy@1 97.209	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [77][0/38]	Time 0.671s (0.671s)	Speed 47.7 samples/s	Data 0.588s (0.588s)	Loss 0.05619 (0.05619)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0479	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [78][0/38]	Time 0.674s (0.674s)	Speed 47.5 samples/s	Data 0.584s (0.584s)	Loss 0.13520 (0.13520)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0478	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [79][0/38]	Time 0.679s (0.679s)	Speed 47.1 samples/s	Data 0.583s (0.583s)	Loss 0.14985 (0.14985)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0467	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [80][0/38]	Time 0.674s (0.674s)	Speed 47.5 samples/s	Data 0.583s (0.583s)	Loss 0.11250 (0.11250)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0438	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [81][0/38]	Time 0.661s (0.661s)	Speed 48.4 samples/s	Data 0.566s (0.566s)	Loss 0.13544 (0.13544)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0431	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [82][0/38]	Time 0.645s (0.645s)	Speed 49.6 samples/s	Data 0.559s (0.559s)	Loss 0.06143 (0.06143)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0454	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [83][0/38]	Time 0.653s (0.653s)	Speed 49.0 samples/s	Data 0.557s (0.557s)	Loss 0.10856 (0.10856)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.163	Loss 0.0441	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [84][0/38]	Time 0.667s (0.667s)	Speed 48.0 samples/s	Data 0.581s (0.581s)	Loss 0.08485 (0.08485)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0416	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [85][0/38]	Time 0.644s (0.644s)	Speed 49.7 samples/s	Data 0.553s (0.553s)	Loss 0.13726 (0.13726)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0454	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [86][0/38]	Time 0.653s (0.653s)	Speed 49.0 samples/s	Data 0.560s (0.560s)	Loss 0.05746 (0.05746)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0462	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [87][0/38]	Time 0.647s (0.647s)	Speed 49.4 samples/s	Data 0.556s (0.556s)	Loss 0.18541 (0.18541)	Accuracy@1 90.625 (90.625)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0462	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [88][0/38]	Time 0.649s (0.649s)	Speed 49.3 samples/s	Data 0.555s (0.555s)	Loss 0.10636 (0.10636)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.157	Loss 0.0480	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [89][0/38]	Time 0.664s (0.664s)	Speed 48.2 samples/s	Data 0.567s (0.567s)	Loss 0.02055 (0.02055)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0428	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [90][0/38]	Time 0.642s (0.642s)	Speed 49.8 samples/s	Data 0.544s (0.544s)	Loss 0.06368 (0.06368)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0422	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [91][0/38]	Time 0.670s (0.670s)	Speed 47.8 samples/s	Data 0.573s (0.573s)	Loss 0.10183 (0.10183)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.158	Loss 0.0482	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [92][0/38]	Time 0.655s (0.655s)	Speed 48.9 samples/s	Data 0.566s (0.566s)	Loss 0.04787 (0.04787)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0402	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [93][0/38]	Time 0.680s (0.680s)	Speed 47.1 samples/s	Data 0.584s (0.584s)	Loss 0.07817 (0.07817)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0459	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [94][0/38]	Time 0.656s (0.656s)	Speed 48.8 samples/s	Data 0.560s (0.560s)	Loss 0.01592 (0.01592)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0435	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [95][0/38]	Time 0.648s (0.648s)	Speed 49.4 samples/s	Data 0.558s (0.558s)	Loss 0.03383 (0.03383)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.161	Loss 0.0418	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [96][0/38]	Time 0.635s (0.635s)	Speed 50.4 samples/s	Data 0.545s (0.545s)	Loss 0.04846 (0.04846)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0450	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [97][0/38]	Time 0.675s (0.675s)	Speed 47.4 samples/s	Data 0.579s (0.579s)	Loss 0.00951 (0.00951)	Accuracy@1 100.000 (100.000)	Accuracy@5 100.000 (100.000)
# Test: Time 0.164	Loss 0.0413	Error@1 0.465	Error@5 0.000	Accuracy@1 99.535	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [98][0/38]	Time 0.656s (0.656s)	Speed 48.8 samples/s	Data 0.561s (0.561s)	Loss 0.06922 (0.06922)	Accuracy@1 96.875 (96.875)	Accuracy@5 100.000 (100.000)
# Test: Time 0.160	Loss 0.0490	Error@1 1.395	Error@5 0.000	Accuracy@1 98.605	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# Epoch: [99][0/38]	Time 0.654s (0.654s)	Speed 48.9 samples/s	Data 0.563s (0.563s)	Loss 0.09682 (0.09682)	Accuracy@1 93.750 (93.750)	Accuracy@5 100.000 (100.000)
# Test: Time 0.159	Loss 0.0437	Error@1 0.930	Error@5 0.000	Accuracy@1 99.070	Accuracy@5 100.000
# => saving checkpoint to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small
# saving final model state to /content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small/final_state.pth.tar

# %%
# %cd /content/HRNet-Image-Classification
# Out:
# /content/HRNet-Image-Classification

# %%
import sys, os

# 레포 루트와 lib 디렉터리를 모듈 탐색 경로에 추가
root = "/content/HRNet-Image-Classification"
lib  = os.path.join(root, "lib")
sys.path.insert(0, root)
sys.path.insert(0, lib)

# 올바르게 추가됐는지 확인
print([p for p in sys.path if "HRNet-Image-Classification" in p])
# Out:
# ['/content/HRNet-Image-Classification/lib', '/content/HRNet-Image-Classification']

# %%
import torch
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, f1_score, recall_score, jaccard_score

# HRNet 의 config/모델 모듈 import
from config import config, update_config
import models
import argparse, os

# 1) Config 업데이트 (train.py 와 동일한 방식)
parser = argparse.ArgumentParser()
parser.add_argument('--cfg',     type=str,
                    default="experiments/cls_hrnet_brain_tumor_small.yaml")
parser.add_argument('--modelDir',type=str, default="")
parser.add_argument('--logDir',  type=str, default="")
parser.add_argument('--dataDir', type=str,
                    default="/content/HRNet-Image-Classification/brain_tumor_classification")
parser.add_argument('--testModel', type=str, default="")
args = parser.parse_args([])
update_config(config, args)

# 2) 모델 생성 & 체크포인트 로드
model = eval(f"models.{config.MODEL.NAME}.get_cls_net")(config)
ckpt = torch.load(
    "/content/drive/MyDrive/Tumor_w18_Small_Output/imagenet/cls_hrnet_brain_tumor_small/model_best.pth.tar",
    map_location="cuda"
)
state_dict = ckpt.get("state_dict", ckpt)
model.load_state_dict(state_dict)
model = torch.nn.DataParallel(model, device_ids=list(config.GPUS)).cuda().eval()

# 3) Test DataLoader 준비
transform = transforms.Compose([
    transforms.Resize((config.MODEL.IMAGE_SIZE[1], config.MODEL.IMAGE_SIZE[0])),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
])
test_dir    = os.path.join(config.DATASET.ROOT, config.DATASET.TEST_SET)
test_ds     = datasets.ImageFolder(test_dir, transform=transform)
test_loader = DataLoader(
    test_ds,
    batch_size=config.TEST.BATCH_SIZE_PER_GPU,
    shuffle=False,
    num_workers=config.WORKERS,
    pin_memory=True
)

# 4) 예측 & 메트릭 계산
all_probs, all_preds, all_labels = [], [], []
with torch.no_grad():
    for imgs, labels in test_loader:
        imgs = imgs.cuda()
        logits = model(imgs)
        probs = torch.softmax(logits, dim=1)[:, 1]  # tumor 확률
        preds = (probs > 0.5).long()
        all_probs .extend(probs.cpu().numpy())
        all_preds .extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

rocauc = roc_auc_score(all_labels, all_probs)
f1     = f1_score    (all_labels, all_preds)
recall = recall_score(all_labels, all_preds)
iou    = jaccard_score(all_labels, all_preds)

print(f"ROC-AUC : {rocauc:.4f}")
print(f"F1      : {f1:.4f}")
print(f"Recall  : {recall:.4f}")
print(f"IoU     : {iou:.4f}")
# Out:
# ROC-AUC : 0.9829
# F1      : 0.9040
# Recall  : 0.8639
# IoU     : 0.8248

# %%
test_dir = os.path.join(config.DATASET.ROOT, "test")
print(test_ds.class_to_idx)      # {'no_tumor': 0, 'tumor': 1}
print(test_ds.classes)           # ['no_tumor','tumor']
# Out:
# {'no_tumor': 0, 'tumor': 1}
# ['no_tumor', 'tumor']

# %%
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(all_labels, all_preds)
print("Confusion Matrix:\n", cm)

print(classification_report(
    all_labels, all_preds,
    target_names=test_ds.classes,
    digits=4
))
# Out:
# Confusion Matrix:
#  [[567  23]
#  [ 66 419]]
#               precision    recall  f1-score   support
#
#     no_tumor     0.8957    0.9610    0.9272       590
#        tumor     0.9480    0.8639    0.9040       485
#
#     accuracy                         0.9172      1075
#    macro avg     0.9218    0.9125    0.9156      1075
# weighted avg     0.9193    0.9172    0.9167      1075
